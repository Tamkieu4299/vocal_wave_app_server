# %%
import os
import numpy as np
import cv2
from tensorflow.keras.utils import to_categorical

from keras.layers import Input, Dense
from keras.models import Model

# %%
is_init = False
size = -1

label = []
dictionary = {}
c = 0

for i in os.listdir():
    if i.split(".")[-1] == "npy" and not(i.split(".")[0]=="labels"):
        if not(is_init):
            is_init = True
            X = np.load(i)
            size = X.shape[0]
            y = np.array([i.split('.')[0]]*size).reshape(-1,1)
        else:
            X = np.concatenate((X, np.load(i)))
            y = np.concatenate((y, np.array([i.split('.')[0]]*size).reshape(-1,1)))

        label.append(i.split('.')[0])
        dictionary[i.split('.')[0]] = c
        c+=1

for i in range(y.shape[0]):
    y[i, 0] = dictionary[y[i,0]]
y = np.array(y, dtype="int32")

y = to_categorical(y)

# %%
X_new = X.copy()
y_new = y.copy()
counter = 0

cnt = np.arange(X.shape[0])
np.random.shuffle(cnt)

for i in cnt:
    X_new[counter] = X[i]
    y_new[counter] = y[i]
    counter +=1

ip = Input(shape=(X_new.shape[1]))

m = Dense(512, activation="relu")(ip)
m = Dense(256, activation="relu")(m)

op = Dense(y_new.shape[1], activation="softmax")(m)

model = Model(inputs=ip, outputs=op)

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

model.fit(X_new, y_new, epochs = 50)

model.save("model.h5")
np.save("labels.npy", np.array(label))
# Out:
# Epoch 1/50
# 22/22 [==============================] - 1s 6ms/step - loss: 1.9316 - acc: 0.1643
# Epoch 2/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.8244 - acc: 0.2357
# Epoch 3/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.7325 - acc: 0.2943
# Epoch 4/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.6521 - acc: 0.3257
# Epoch 5/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.5765 - acc: 0.3843
# Epoch 6/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.4984 - acc: 0.4143
# Epoch 7/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.4559 - acc: 0.4671
# Epoch 8/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.3647 - acc: 0.4986
# Epoch 9/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.3157 - acc: 0.5400
# Epoch 10/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.2189 - acc: 0.5971
# Epoch 11/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1977 - acc: 0.5871
# Epoch 12/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1156 - acc: 0.6414
# Epoch 13/50
# 22/22 [==============================] - 0s 6ms/step - loss: 1.0869 - acc: 0.6386
# Epoch 14/50
# 22/22 [==============================] - 0s 6ms/step - loss: 0.9953 - acc: 0.6986
# Epoch 15/50
# 22/22 [==============================] - 0s 7ms/step - loss: 0